# %% [markdown]
# # [Original Problem - Wolfram](https://challenges.wolframcloud.com/challenge/almost-palindromes)
#
# ## Almost Palindromes
#
# Write a function that finds words that would be palindromes if one of their letters was removed.
# A palindrome is a word, like "racecar," that is spelled the same backwards as it is forwards. The word "engage" is not a palindrome, but if we remove the letter "n" then the remaining string of letters - "egage" - uses the same sequence of characters whether it is read from left to right or right to left. We might say that "engage" is an "almost palindrome."
#
# ### What Your Function Should Do
#
# Write a function called AlmostPalindrome that takes a positive integer n and returns a list of all words in DictionaryLookup[] of length n that are not palindromes but would be palindromes if exactly one letter was removed. The list of words that your function outputs should be arranged in alphabetical order.
#
# ```
# In[1]:= AlmostPalindrome[5]
# Out[1]= {
#     allay, annal, arras, array, assay, attar, belle, Bette, boffo,
#     boobs, booby, calla, cirri, deeds, ebbed, effed, egged, erred,
#     freer, gamma, Greer, Hakka, Hanna, Hesse, hooch, innit, Janna,
#     Jesse, kappa, kooks, kooky, Lassa, lemme, Lippi, lotto, manna,
#     motto, Nikki, noons, peeps, poops, ragga, recce, Rocco, Rollo,
#     seeds, seeks, seems, seeps, seers, sells, setts, shoos, sills,
#     teeth, tooth, toots, tweet, villi, walla, wanna, yobbo, yukky,
#     yummy, Zappa, Zorro
# }
# ```
#
# #### More Examples
#
# ```
# In[2]:= AlmostPalindrome[3]
# Out[2]= {
#     aah, add, all, Ann, ass, baa, BBC, bee, boo, brr, CNN, coo, DDT,
#     Dee, ebb, eek, eel, eff, egg, ell, err, fee, gee, goo, ill, inn,
#     lee, Lee, LLB, loo, moo, nee, odd, off, ooh, Orr, pee, ppm, see,
#     shh, ssh, tee, too, wee, woo, XXL, zoo
# }
#
# In[3]:= AlmostPalindrome[4]
# Out[3]= {
#     afar, agar, agog, ahas, ajar, alas, alga, anal, anon, aqua, area,
#     aria, asap, asks, asps, aura, away, ayah, babe, baby, barb, Bede,
#     bibs, blab, blob, bobs, bomb, bozo, bubo, bubs, bulb, Cara, ceca,
#     cede, chic, choc, coca, cock, coco, coho, Colo, Como, Dada, dado,
#     dads, Dana, data, dead, Dene, dido, died, dodo, dude, duds, DVDs,
#     dyad, dyed, ease, eave, edge, e'en, e'er, eked, ekes, else, Elul,
#     epee, &eacute;p&eacute;e, even, ever, eves, ewer, ewes, exec, exes,
#     eyed, eyes, faff, fete, fief, fife, Fiji, Gaea, gaga, gage, gags,
#     gala, Gama, gang, Gaza, gene, Gene, gigs, gong, grog, guru, hash,
#     hath, Hebe, heme, here, high, hobo, huhs, hush, Hutu, ibis, ilia,
#     imam, inti, iris, Isis, isms, Jana, java, Java, Kama, Kara, kick,
#     kink, kirk, kiwi, lama, Lana, Lara, lava, lilo, lilt, lily, loco,
#     logo, loll, luau, lull, lulu, Lulu, Lvov, Lyly, Maia, maim, mama,
#     mams, Mara, Maya, memo, mere, mete, midi, mime, Mimi, mini, Moho,
#     moms, mono, Moro, Mses, mums, nans, Nara, NASA, neon, nine, none,
#     noun, nuns, oboe, odor, ohos, oleo, onto, orzo, ouzo, papa, paps,
#     para, peke, Pele, peps, Pete, pimp, pipe, pips, plop, pogo, Pogo,
#     polo, Polo, pomp, pope, pops, prep, prop, psis, pulp, pump, pupa,
#     pups, raga, Rama, rare, rear, Rene, roar, Saba, sacs, saga, sags,
#     Sana, sans, saps, Sara, sash, sass, saws, says, seas, secs, sens,
#     sere, sets, sews, shah, shes, sics, sins, sips, sirs, sits, skis,
#     sobs, socs, sods, Soho, solo, sols, sons, sops, Soto, sots, sous,
#     sows, spas, stet, subs, suds, sues, sums, suns, sups, suss, tact,
#     Tana, Tara, tart, tats, taut, teat, tent, test, text, that, tilt,
#     tint, Togo, Tojo, tort, tote, Toto, tots, tout, trot, tuft, tuts,
#     tutu, Tutu, twit, uses, viva, were, whew, wows, Yoko, Zeke, Zulu
# }
#
# In[4]:= AlmostPalindrome[2]
# Out[4]= {
#     AC, ad, AD, ah, am, AM, an, as, at, ax, BC, be, bi, by, CD, cs, cw,
#     db, dB, dc, DJ, do, Ed, eh, em, en, er, es, ET, ex, fa, FM, GE, GI,
#     go, GP, gs, ha, he, hi, hm, ho, HQ, id, ID, if, in, IQ, is, it, IT,
#     jg, Jo, kc, KO, ks, kw, kW, la, Le, lo, ls, ma, MC, me, mi, Mr, ms,
#     Ms, mu, my, no, nu, of, oh, oi, OK, om, on, or, ow, ox, Oz, pa, PC,
#     pH, pi, PM, re, Rh, rs, Rx, sh, so, ta, TB, ti, TM, to, ts, TV, Ty,
#     uh, UK, um, UN, up, us, US, vs, we, Wm, Wu, xi, XL, ya, ye, yo
# }
# ```

# %%
WORDS = open('../codebreak/canyouhackit/data/words.txt').read().split('\n')
def almost_palindrome(n: int, k: int) -> list:
    words_of_size_n = [w for w in WORDS if len(w) == n]
    almost_pal_words = []

    for word in words_of_size_n:
        if word == ''.join(reversed(word)):
            # We only want words that are almost palindrome
            # meaning can be formed palindrome if one letter is removed
            almost_pal_words.append(word)
            continue

        pal, can_make = make_palindrome(word, k)
        if can_make:
            almost_pal_words.append((word, pal))
    return almost_pal_words

def make_palindrome(word: str, k: int) -> bool:
    # K is the number of deletion
    i = 0
    n = len(word)
    j = n - 1
    count = 0
    result = ['' for _ in range(n)]

    while i <= j:
        if word[i] != word[j]:
            if word[i] == word[j - 1]:
                j -= 1
            elif word[i + 1] == word[j]:
                i += 1
            else:
                return (word, False) # Too many to delete

            count += 1
            continue

        result[i] = word[i]
        result[j] = word[j]
        i += 1
        j -= 1
    if count == k or count == 0:
        return (''.join(result), True)
    return (word, False) # Too many to delete

n, k = 5, 1 # length of word and k is the number of deletion
res = almost_palindrome(n, k)
print(res)
# Out:
# [('abbas', 'abba'), ('ACCRA', 'ACCA'), ('addax', 'adda'), 'addda', ('allay', 'alla'), 'alula', ('annal', 'anna'), ('annas', 'anna'), ('annat', 'anna'), ('apoop', 'poop'), ('appay', 'appa'), ('appal', 'appa'), ('appar', 'appa'), ('arrah', 'arra'), ('array', 'arra'), ('arrha', 'arra'), ('assai', 'assa'), ('assay', 'assa'), ('attal', 'atta'), ('attar', 'atta'), ('bacca', 'acca'), ('Balla', 'alla'), ('Banna', 'anna'), ('Barra', 'arra'), ('Bassa', 'assa'), ('Batta', 'atta'), ('Belle', 'elle'), ('benne', 'enne'), ('Besse', 'esse'), ('Bette', 'ette'), ('Billi', 'illi'), ('Binni', 'inni'), ('birri', 'irri'), ('boffo', 'offo'), ('booby', 'boob'), ('boobs', 'boob'), ('bussu', 'ussu'), ('caffa', 'affa'), ('Calla', 'alla'), 'CAMAC', ('Canna', 'anna'), ('CCCCM', 'CCCC'), ('Celle', 'elle'), ('cippi', 'ippi'), ('Cirri', 'irri'), 'civic', ('commo', 'ommo'), ('cooch', 'cooc'), ('dabba', 'abba'), ('Dacca', 'acca'), ('dagga', 'agga'), ('Danna', 'anna'), ('Darra', 'arra'), ('deedy', 'deed'), ('deeds', 'deed'), 'deked', 'deled', ('Delle', 'elle'), ('dette', 'ette'), 'dewed', ('dilli', 'illi'), 'divid', ('doggo', 'oggo'), ('dreed', 'deed'), ('ebbed', 'ebbe'), ('ebbet', 'ebbe'), ('edder', 'edde'), ('effet', 'effe'), ('egged', 'egge'), ('egger', 'egge'), ('emmew', 'emme'), ('ennew', 'enne'), ('entte', 'ette'), ('erred', 'erre'), ('essed', 'esse'), ('essee', 'esse'), ('esses', 'esse'), ('ESSEX', 'ESSE'), ('ettle', 'ette'), ('Falla', 'alla'), ('Farra', 'arra'), ('femme', 'emme'), ('fesse', 'esse'), ('Freer', 'reer'), ('Galla', 'alla'), ('Gamma', 'amma'), ('Gibbi', 'ibbi'), ('Gilli', 'illi'), ('Ginni', 'inni'), ('Greer', 'reer'), ('Hakka', 'akka'), ('Halla', 'alla'), ('Hanna', 'anna'), ('Hatta', 'atta'), ('Hebbe', 'ebbe'), ('Helle', 'elle'), ('Hesse', 'esse'), ('HIPPI', 'IPPI'), ('hocco', 'occo'), ('hollo', 'ollo'), ('hoosh', 'hooh'), ('hoppo', 'oppo'), ('yabby', 'ybby'), ('yacca', 'acca'), ('yakka', 'akka'), ('yalla', 'alla'), ('yappy', 'yppy'), 'yaray', ('yarry', 'yrry'), ('iddhi', 'iddi'), ('yezzy', 'yzzy'), ('immis', 'immi'), ('immit', 'immi'), ('immix', 'immi'), ('yobbo', 'obbo'), ('yocco', 'occo'), ('yummy', 'ymmy'), ('Jadda', 'adda'), ('Jaffa', 'affa'), ('Janna', 'anna'), ('jarra', 'arra'), ('Jelle', 'elle'), ('Jenne', 'enne'), ('Jerre', 'erre'), ('Jesse', 'esse'), ('Jilli', 'illi'), ('jinni', 'inni'), 'kaiak', 'kayak', ('kappa', 'appa'), ('Kassa', 'assa'), ('keeks', 'keek'), 'kelek', ('Kemme', 'emme'), ('kesse', 'esse'), ('kette', 'ette'), ('Kimmi', 'immi'), ('Kitti', 'itti'), ('kooka', 'kook'), ('kooky', 'kook'), ('kooks', 'kook'), ('Kotto', 'otto'), ('labba', 'abba'), ('lacca', 'acca'), ('Lalla', 'alla'), ('Lanna', 'anna'), ('Lappa', 'appa'), ('Lassa', 'assa'), ('Latta', 'atta'), ('LCCLN', 'LCCL'), ('Lecce', 'ecce'), ('Legge', 'egge'), 'lemel', ('Lette', 'ette'), 'level', ('Libbi', 'ibbi'), ('Lilli', 'illi'), ('Lippi', 'ippi'), ('Lissi', 'issi'), ('Livvi', 'ivvi'), ('lotto', 'otto'), "ma'am", 'madam', ('Maffa', 'affa'), 'malam', ('manna', 'anna'), ('Marra', 'arra'), ('Massa', 'assa'), ('Matta', 'atta'), 'mesem', ('messe', 'esse'), ('Milli', 'illi'), 'minim', ('Minni', 'inni'), ('Missi', 'issi'), ('Moppo', 'oppo'), ('morro', 'orro'), ('mosso', 'osso'), ('motto', 'otto'), 'MRSRM', ('Nadda', 'adda'), ('namma', 'amma'), ('Nanna', 'anna'), ('nappa', 'appa'), ('Narra', 'arra'), ('Nassa', 'assa'), ('Natta', 'atta'), ('needn', 'neen'), ('Nelle', 'elle'), ('Nette', 'ette'), 'neven', ('Nihhi', 'ihhi'), ('Nikki', 'ikki'), ('Nitti', 'itti'), ('noons', 'noon'), ('orrow', 'orro'), ('ottos', 'otto'), ('Padda', 'adda'), ('Palla', 'alla'), ('Panna', 'anna'), ('Parra', 'arra'), ('patta', 'atta'), ('peepy', 'peep'), ('peeps', 'peep'), ('Pirri', 'irri'), ('poops', 'poop'), ('Poppo', 'oppo'), ('potto', 'otto'), 'RADAR', ('Ranna', 'anna'), ('rebbe', 'ebbe'), ('recce', 'ecce'), 'refer', ('renne', 'enne'), 'rever', ('Ricci', 'icci'), ('Riffi', 'iffi'), ('Rikki', 'ikki'), ('Rizzi', 'izzi'), ('Rocco', 'occo'), ('Rollo', 'ollo'), 'rotor', 'RSFSR', ('Sabba', 'abba'), 'sa ...

# %%
n, k = 4, 1 # length of word and k is the number of deletion
res = almost_palindrome(n, k)
print(res)
# Out:
# [('1080', '080'), ('A.B.', '.B.'), ('A.C.', '.C.'), ('A.D.', '.D.'), ('A.F.', '.F.'), ('A.G.', '.G.'), ('A.H.', '.H.'), ('A.I.', '.I.'), ('A.L.', '.L.'), ('A.M.', '.M.'), ('A.N.', '.N.'), ('a.p.', '.p.'), ('a.r.', '.r.'), ('A.U.', '.U.'), ('A.V.', '.V.'), ('a.w.', '.w.'), 'AAAA', ('AAAL', 'AAA'), ('AAAS', 'AAA'), ('Aara', 'ara'), ('abac', 'aba'), ('abay', 'aba'), ('Abib', 'bib'), ('ACAA', 'ACA'), ('acad', 'aca'), ('acal', 'aca'), ('ACAS', 'ACA'), 'acca', ('ACDA', 'ACA'), ('acea', 'aca'), ('ACWA', 'ACA'), ('Adad', 'dad'), ('adat', 'ada'), ('adaw', 'ada'), ('ADMD', 'DMD'), ('adod', 'dod'), ('AFAM', 'AFA'), 'affa', ('agad', 'aga'), ('Agag', 'gag'), ('agal', 'aga'), ('agas', 'aga'), ('agba', 'aga'), ('AGCA', 'AGA'), ('agha', 'aga'), ('agla', 'aga'), ('AGMA', 'AGA'), ('agog', 'gog'), ('agua', 'aga'), ('AHSA', 'AHA'), ('AIAA', 'AIA'), ('ayah', 'aya'), ('Aili', 'ili'), ('AISI', 'ISI'), ('ajar', 'aja'), ('akia', 'aka'), ('alae', 'ala'), ('alay', 'ala'), ('ALAP', 'ALA'), ('ALFA', 'ALA'), ('alga', 'ala'), ('amah', 'ama'), ('amay', 'ama'), ('amas', 'ama'), ('AMAT', 'AMA'), ('AMBA', 'AMA'), ('amla', 'ama'), ('amra', 'ama'), ('ana-', 'ana'), ("an'a", 'ana'), ('ANAC', 'ANA'), ('anay', 'ana'), ('anal', 'ana'), ('anan', 'ana'), ('anba', 'ana'), ('anda', 'ana'), ('anga', 'ana'), ('anoa', 'ana'), ('anon', 'non'), ('ANPA', 'ANA'), ('ansa', 'ana'), ('ANTA', 'ANA'), ('AOPA', 'AOA'), ('apay', 'apa'), ('apar', 'apa'), ('APDA', 'APA'), ('APRA', 'APA'), ('APSA', 'APA'), ('aqua', 'aqa'), ('arar', 'ara'), ('arba', 'ara'), ('arca', 'ara'), ('area', 'ara'), ('arna', 'ara'), ('ARPA', 'ARA'), ('ARSA', 'ARA'), ('asak', 'asa'), ('ASAP', 'ASA'), ('asea', 'asa'), ('asis', 'sis'), ('asks', 'sks'), ('asps', 'sps'), ('ASRS', 'SRS'), ('AT&T', 'T&T'), ('atap', 'ata'), ('atar', 'ata'), ('Atat', 'tat'), ('ATDA', 'ATA'), ('atma', 'ata'), ('atua', 'ata'), ('aula', 'aua'), ('aulu', 'ulu'), ('AURA', 'AUA'), ('ausu', 'usu'), ('aval', 'ava'), ('Aviv', 'viv'), ('awag', 'awa'), ('away', 'awa'), ('awat', 'awa'), ('AWEA', 'AWA'), ('AXAF', 'AXA'), ('axal', 'axa'), ('aza-', 'aza'), ('B.A.', '.A.'), ('B.C.', '.C.'), ('B.D.', '.D.'), ('B.E.', '.E.'), ('b.f.', '.f.'), ('B.L.', '.L.'), ('B.M.', '.M.'), ('B.O.', '.O.'), ('B.P.', '.P.'), ('B.S.', '.S.'), ('B.V.', '.V.'), ('Baba', 'aba'), ('baby', 'bab'), ('babu', 'bab'), ('baga', 'aga'), ('Baya', 'aya'), ('Baja', 'aja'), ('baka', 'aka'), ('Bala', 'ala'), ('Bana', 'ana'), ('Bara', 'ara'), ('BCBS', 'BCB'), ('Bebe', 'ebe'), ('Bede', 'ede'), ('beme', 'eme'), ('Bene', 'ene'), ('bere', 'ere'), ('bete', 'ete'), ('bibb', 'bib'), ('Bibi', 'ibi'), ('bibs', 'bib'), ('bidi', 'idi'), ('Bili', 'ili'), ('Bini', 'ini'), ('biri', 'iri'), ('biti', 'iti'), ('blab', 'blb'), ('bleb', 'blb'), ('blob', 'blb'), ('blub', 'blb'), ('boba', 'bob'), ('Bobo', 'obo'), ('bobs', 'bob'), ('Bodo', 'odo'), ('Bogo', 'ogo'), ('boho', 'oho'), ('boyo', 'oyo'), ('bojo', 'ojo'), ('boko', 'oko'), ('Bolo', 'olo'), ('bomb', 'bob'), ('Bono', 'ono'), 'boob', ('Boro', 'oro'), ('bozo', 'ozo'), ('brab', 'brb'), ('brob', 'brb'), ('brrr', 'rrr'), ('BSBA', 'BSB'), ('BSBH', 'BSB'), ('BSES', 'SES'), ('BSFS', 'SFS'), ('BSLS', 'SLS'), ('BSSS', 'SSS'), ('buba', 'bub'), ('bubs', 'bub'), ('bulb', 'bub'), ('C.A.', '.A.'), ('C.B.', '.B.'), ('C.C.', 'C.C'), ('C.D.', '.D.'), ('C.E.', '.E.'), ('C.F.', '.F.'), ('C.G.', '.G.'), ('c.h.', '.h.'), ('C.I.', '.I.'), ('c.m.', '.m.'), ('C.O.', '.O.'), ('C.P.', '.P.'), ('C.R.', '.R.'), ('C.S.', '.S.'), ('C.T.', '.T.'), ('caba', 'aba'), ('cac-', 'cac'), ('Caca', 'aca'), ('cace', 'cac'), ('caci', 'cac'), ('cack', 'cac'), ('CACM', 'CAC'), ('Caia', 'aia'), ('caic', 'cac'), ('calc', 'cac'), ('CAMA', 'AMA'), ('Cana', 'ana'), ('canc', 'cac'), ('capa', 'apa'), ('Cara', 'ara'), ('Casa', 'asa'), ('cava', 'ava'), ('caza', 'aza'), ('CCCI', 'CCC'), ('CCNC', 'CCC'), ('CDCF', 'CDC'), ('ceca', 'cec'), ('Cece', 'ece'), ('cede', 'ede'), ('cele', 'ele'), ('cene', 'ene'), ('cepe', 'epe'), ('Cete', 'ete'), ('CFCA', 'CFC'), ('CGCT', 'CGC'), ('chih', 'hih'), ('CIAC', 'CIC'), ('CICA ...

# %%
n, k = 2, 1 # length of word and k is the number of deletion
res = almost_palindrome(n, k)
print(res)
# Out:
# [('&c', '&'), ('2D', '2'), ('3D', '3'), ('3M', '3'), ('4H', '4'), ("a'", 'a'), ('a-', 'a'), ('A.', 'A'), ('A1', 'A'), ('A4', 'A'), ('A5', 'A'), 'AA', ('AB', 'A'), ('ac', 'a'), ('ad', 'a'), ('ae', 'a'), ('AF', 'A'), ('AG', 'A'), ('AH', 'A'), ('AI', 'A'), ('AY', 'A'), ('AJ', 'A'), ('AK', 'A'), ('al', 'a'), ('AM', 'A'), ('an', 'a'), ('AO', 'A'), ('AP', 'A'), ('AQ', 'A'), ('ar', 'a'), ('AS', 'A'), ('as', 'a'), ('AT', 'A'), ('AU', 'A'), ('AV', 'A'), ('AW', 'A'), ('Ax', 'A'), ('AZ', 'A'), ('B-', 'B'), ('BA', 'B'), 'BB', ('BC', 'B'), ('BD', 'B'), ('BE', 'B'), ('BF', 'B'), ('BG', 'B'), ('BH', 'B'), ('BI', 'B'), ('by', 'b'), ('Bk', 'B'), ('BL', 'B'), ('BM', 'B'), ('BN', 'B'), ('BO', 'B'), ('BP', 'B'), ('BR', 'B'), ('BS', 'B'), ('BT', 'B'), ('BU', 'B'), ('BV', 'B'), ('BW', 'B'), ('BX', 'B'), ('Bz', 'B'), ('C.', 'C'), ('C3', 'C'), ('CA', 'C'), ('CB', 'C'), 'CC', ('CD', 'C'), ('CE', 'C'), ('CF', 'C'), ('CG', 'C'), ('CH', 'C'), ('CI', 'C'), ('cy', 'c'), ('CJ', 'C'), ('ck', 'c'), ('CL', 'C'), ('CM', 'C'), ('CN', 'C'), ('CO', 'C'), ('CP', 'C'), ('CQ', 'C'), ('CR', 'C'), ('CS', 'C'), ('CT', 'C'), ('CU', 'C'), ('CV', 'C'), ('CW', 'C'), ('CZ', 'C'), ("d'", 'd'), ('d-', 'd'), ("'d", "'"), ('D.', 'D'), ('DA', 'D'), ('DB', 'D'), ('DC', 'D'), 'DD', ('DE', 'D'), ('DF', 'D'), ('DG', 'D'), ('DH', 'D'), ('DI', 'D'), ('Dy', 'D'), ('DJ', 'D'), ('DK', 'D'), ('dl', 'd'), ('DM', 'D'), ('DN', 'D'), ('DO', 'D'), ('DP', 'D'), ('DQ', 'D'), ('DR', 'D'), ('DS', 'D'), ('DT', 'D'), ('DU', 'D'), ('DV', 'D'), ('DW', 'D'), ('DX', 'D'), ('DZ', 'D'), ('e-', 'e'), ('E.', 'E'), ('EA', 'E'), ('Eb', 'E'), ('EC', 'E'), ('ed', 'e'), 'ee', ('EF', 'E'), ('EG', 'E'), ('eh', 'e'), ('EI', 'E'), ('ey', 'e'), ('el', 'e'), ('EM', 'E'), ('en', 'e'), ('EO', 'E'), ('EP', 'E'), ('EQ', 'E'), ('er', 'e'), ('es', 'e'), ('et', 'e'), ('Eu', 'E'), ('EV', 'E'), ('EW', 'E'), ('Ex', 'E'), ('Ez', 'E'), ('f.', 'f'), ('FA', 'F'), ('FB', 'F'), ('FC', 'F'), ('FD', 'F'), ('FE', 'F'), 'FF', ('fg', 'f'), ('FI', 'F'), ('fy', 'f'), ('FL', 'F'), ('FM', 'F'), ('fn', 'f'), ('FO', 'F'), ('FP', 'F'), ('FR', 'F'), ('FS', 'F'), ('FT', 'F'), ('Fu', 'F'), ('FV', 'F'), ('FW', 'F'), ('FX', 'F'), ('fz', 'f'), ('G.', 'G'), ('GA', 'G'), ('GB', 'G'), ('GC', 'G'), ('GD', 'G'), ('GE', 'G'), 'GG', ('GH', 'G'), ('GI', 'G'), ('Gy', 'G'), ('Gk', 'G'), ('Gl', 'G'), ('GM', 'G'), ('GN', 'G'), ('GO', 'G'), ('GP', 'G'), ('GQ', 'G'), ('GR', 'G'), ('GS', 'G'), ('GT', 'G'), ('GU', 'G'), ('gv', 'g'), ('GW', 'G'), ('h.', 'h'), ('HA', 'H'), ('HB', 'H'), ('HC', 'H'), ('HD', 'H'), ('HE', 'H'), ('HF', 'H'), ('HG', 'H'), 'HH', ('HI', 'H'), ('Hy', 'H'), ('HJ', 'H'), ('HK', 'H'), ('HL', 'H'), ('HM', 'H'), ('HO', 'H'), ('HP', 'H'), ('HQ', 'H'), ('HR', 'H'), ('HS', 'H'), ('HT', 'H'), ('HU', 'H'), ('HV', 'H'), ('HW', 'H'), ('HZ', 'H'), ("i'", 'i'), ('i-', 'i'), ('y-', 'y'), ('i.', 'i'), ('Y.', 'Y'), ('ia', 'i'), ('YA', 'Y'), ('IB', 'I'), ('YB', 'Y'), ('ic', 'i'), ('id', 'i'), ('yd', 'y'), ('ie', 'i'), ('ye', 'y'), ('IF', 'I'), ('IG', 'I'), 'ii', ('Iy', 'I'), ('Yi', 'Y'), 'YY', ('Ij', 'I'), ('ik', 'i'), ('il', 'i'), ('yl', 'y'), ('IM', 'I'), ('ym', 'y'), ('in', 'i'), ('yn', 'y'), ('IO', 'I'), ('yo', 'y'), ('IP', 'I'), ('YP', 'Y'), ('IQ', 'I'), ('IR', 'I'), ('yr', 'y'), ('is', 'i'), ('ys', 'y'), ('IT', 'I'), ('YT', 'Y'), ('IU', 'I'), ('YU', 'Y'), ('IV', 'I'), ('YV', 'Y'), ('IW', 'I'), ('IX', 'I'), ('Iz', 'I'), ('J.', 'J'), ('JA', 'J'), ('JC', 'J'), ('JD', 'J'), ('Je', 'J'), ('jg', 'j'), ('ji', 'j'), ('Jy', 'J'), 'JJ', ('Jl', 'J'), ('JO', 'J'), ('JP', 'J'), ('Jr', 'J'), ('js', 'j'), ('jt', 'j'), ('Ju', 'J'), ('JV', 'J'), ('K.', 'K'), ('K2', 'K'), ('K9', 'K'), ('Ka', 'K'), ('KB', 'K'), ('KC', 'K'), ('KD', 'K'), ('KE', 'K'), ('KG', 'K'), ('KI', 'K'), ('KY', 'K'), ('kJ', 'k'), ('kl', 'k'), ('km', 'k'), ('KN', 'K'), ('KO', 'K'), ('KP', 'K'), ('KR', 'K'), ('KS', 'K'), ('KT', 'K'), ('Ku', 'K'), ('KV', 'K'), ('KW', 'K'), ('l-', 'l'), ('L.', 'L'), ('L1', 'L'), ('L2', 'L'), ('L3', 'L'), ('L4', 'L'), ('L5', 'L'), ('LA', 'L'), ('LB', 'L'), ('LC', 'L'), ('LD',  ...
